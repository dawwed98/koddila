# %%
# Install missing dependencies

import plotly.offline as pyo
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

import cufflinks as cf
cf.go_offline()

import pandas as pd
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-1.58.4.min"</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-1.58.4.min"</script>

# %%
df = pd.read_csv('OECDBLI2017.csv')
df.head()
# Out:
#      Country  Dwellings without basic facilities as pct  \
# 0  Australia                                        1.1
# 1    Austria                                        1.0
# 2    Belgium                                        2.3
# 3     Canada                                        0.2
# 4      Chile                                        9.4
#
#    Housing expenditure as pct  Rooms per person as rat  \
# 0                          20                      2.3
# 1                          21                      1.6
# 2                          21                      2.2
# 3                          22                      2.5
# 4                          18                      1.9
#
#    Household net adjusted disposable income in usd  \
# 0                                            33417
# 1                                            32544
# 2                                            29968
# 3                                            29850
# 4                                            16588
#
#    Household net financial wealth in usd  Labour market insecurity as pct  \
# 0                                  57462                              4.3
# 1                                  59574                              2.7
# 2                                 104084                              4.8
# 3                                  85758                              3.9
# 4                                  21409                              8.1
#
#    Employment rate as pct  Long-term unemployment rate as pct  \
# 0                      72                                1.36
# 1                      72                                1.94
# 2                      62                                3.98
# 3                      73                                0.81
# 4                      62                                2.02
#
#    Personal earnings in usd  ...  Water quality as pct  \
# 0                     52063  ...                    92
# 1                     48295  ...                    93
# 2                     49587  ...                    84
# 3                     48403  ...                    91
# 4                     28434  ...                    69
#
#    Stakeholder engagement for developing regulations as avg score  \
# 0                                                2.7
# 1                                                1.3
# 2                                                2.2
# 3                                                3.0
# 4                                                1.5
#
#    Voter turnout as pct  Life expectancy in yrs  Self-reported health as pct  \
# 0                    91                    82.5                           85
# 1                    75                    81.3                           70
# 2                    89                    81.1                           75
# 3                    68                    81.5                           88
# 4                    49                    79.1                           57
#
#    Life satisfaction as avg score  Feeling safe walking alone at night as pct  \
# 0                             7.3                                        63.6
# 1                             7.0                                        80.7
# 2                             6.9                                        70.7
# 3                             7.3                                        80.9
# 4                             6.7                                        51.1
#
#    Homicide rate as rat  Employees working very long hours as pct  \
# 0                   1.0                                     13.20
# 1                   0.4                                      6.78
# 2                   1.0                                      4.31
# 3                   1.4                                      3.73
# 4                   4.5                                     10.06
#
#    Time devoted to leisure and personal care in hrs
# 0                                             14.35
# 1                                             14.55
# 2                                             15.77
# 3                                             14.41
# 4                                             14.90
#
# [5 rows x 25 columns]

# %%
df = pd.read_csv('OECDBLI2017.csv')
df.set_index('Country')['Employment rate as pct'].sort_values(ascending=False).iplot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 df = pd.read_csv('OECDBLI2017.csv')
# ----> 2 df.set_index('Country')['Employment rate as pct'].sort_values(ascending=False).iplot(kind='bar', color='orange')
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\cufflinks\plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\cufflinks\plotlytools.py:159, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     157 			lines[key]["fillcolor"]=to_rgba(colors[key],kwargs['opacity'] if 'opacity' in kwargs else .3		)
#     158 if 'bar' in kind:
# --> 159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
#     161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\graph_objs\_bar.py:2957, in __init__(self, arg, alignmentgroup, base, basesrc, cliponaxis, constraintext, customdata, customdatasrc, dx, dy, error_x, error_y, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextanchor, insidetextfont, legendgroup, marker, meta, metasrc, name, offset, offsetgroup, offsetsrc, opacity, orientation, outsidetextfont, r, rsrc, selected, selectedpoints, showlegend, stream, t, text, textangle, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, tsrc, uid, uirevision, unselected, visible, width, widthsrc, x, x0, xaxis, xcalendar, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yperiod, yperiod0, yperiodalignment, ysrc, **kwargs)
#    2704 def __init__(
#    2705     self,
#    2706     arg=None,
#    (...)   2781     **kwargs,
#    2782 ):
#    2783     """
#    2784     Construct a new Bar object
#    2785
#    2786     The data visualized by the span of the bars is set in `y` if
#    2787     `orientation` is set to "v" (the default) and the labels are
#    2788     set in `x`. By setting `orientation` to "h", the roles are
#    2789     interchanged.
#    2790
#    2791     Parameters
#    2792     ----------
#    2793     arg
#    2794         dict of properties compatible with this constructor or
#    2795         an instance of :class:`plotly.graph_objs.Bar`
#    2796     alignmentgroup
#    2797         Set several traces linked to the same position axis or
#    2798         matching axes to the same alignmentgroup. This controls
#    2799         whether bars compute their positional range dependently
#    2800         or independently.
#    2801     base
#    2802         Sets where the bar base is drawn (in position axis
#    2803         units). In "stack" or "relative" barmode, traces that
#    2804         set "base" will be excluded and drawn in "overlay" mode
#    2805         instead.
#    2806     basesrc
#    2807         Sets the source reference on Chart Studio Cloud for
#    2808         `base`.
#    2809     cliponaxis
#    2810         Determines whether the text nodes are clipped about the
#    2811         subplot axes. To show the text nodes above axis lines
#    2812         and tick labels, make sure to set `xaxis.layer` and
#    2813         `yaxis.layer` to *below traces*.
#    2814     constraintext
#    2815         Constrain the size of text inside or outside a bar to
#    2816         be no larger than the bar itself.
#    2817     customdata
#    2818         Assigns extra data each datum. This may be useful when
#    2819         listening to hover, click and selection events. Note
#    2820         that, "scatter" traces also appends customdata items in
#    2821         the markers DOM elements
#    2822     customdatasrc
#    2823         Sets the source reference on Chart Studio Cloud for
#    2824         `customdata`.
#    2825     dx
#    2826         Sets the x coordinate step. See `x0` for more info.
#    2827     dy
#    2828         Sets the y coordinate step. See `y0` for more info.
#    2829     error_x
#    2830         :class:`plotly.graph_objects.bar.ErrorX` instance or
#    2831         dict with compatible properties
#    2832     error_y
#    2833         :class:`plotly.graph_objects.bar.ErrorY` instance or
#    2834         dict with compatible properties
#    2835     hoverinfo
#    2836         Determines which trace information appear on hover. If
#    2837         `none` or `skip` are set, no information is displayed
#    2838         upon hovering. But, if `none` is set, click and hover
#    2839         events are still fired.
#    2840     hoverinfosrc
#    2841         Sets the source reference on Chart Studio Cloud for
#    2842         `hoverinfo`.
#    2843     hoverlabel
#    2844         :class:`plotly.graph_objects.bar.Hoverlabel` instance
#    2845         or dict with compatible properties
#    2846     hovertemplate
#    2847         Template string used for rendering the information that
#    2848         appear on hover box. Note that this will override
#    2849         `hoverinfo`. Variables are inserted using %{variable},
#    2850         for example "y: %{y}" as well as %{xother}, {%_xother},
#    2851         {%_xother_}, {%xother_}. When showing info for several
#    2852         points, "xother" will be added to those with different
#    2853         x positions from the first point. An underscore before
#    2854         or after "(x|y)other" will add a space on that side,
#    2855         only when this field is shown. Numbers are formatted
#    2856         using d3-format's syntax %{variable:d3-format}, for
#    2857         example "Price: %{y:$.2f}".
#    2858         https://github.com/d3/d3-format/tree/v1.4.5#d3-format
#    2859         for details on the formatting syntax. Dates are
#    2860         formatted using d3-time-format's syntax
#    2861         %{variable|d3-time-format}, for example "Day:
#    2862         %{2019-01-01|%A}". https://github.com/d3/d3-time-
#    2863         format/tree/v2.2.3#locale_format for details on the
#    2864         date formatting syntax. The variables available in
#    2865         `hovertemplate` are the ones emitted as event data
#    2866         described at this link
#    2867         https://plotly.com/javascript/plotlyjs-events/#event-
#    2868         data. Additionally, every attributes that can be
#    2869         specified per-point (the ones that are `arrayOk: true`)
#    2870         are available. Finally, the template string has access
#    2871         to variables `value` and `label`. Anything contained in
#    2872         tag `<extra>` is displayed in the secondary box, for
#    2873         example "<extra>{fullData.name}</extra>". To hide the
#    2874         secondary box completely, use an empty tag
#    2875         `<extra></extra>`.
#    2876     hovertemplatesrc
#    2877         Sets the source reference on Chart Studio Cloud for
#    2878         `hovertemplate`.
#    2879     hovertext
#    2880         Sets hover text elements associated with each (x,y)
#    2881         pair. If a single string, the same string appears over
#    2882         all the data points. If an array of string, the items
#    2883         are mapped in order to the this trace's (x,y)
#    2884         coordinates. To be seen, trace `hoverinfo` must contain
#    2885         a "text" flag.
#    2886     hovertextsrc
#    2887         Sets the source reference on Chart Studio Cloud for
#    2888         `hovertext`.
#    2889     ids
#    2890         Assigns id labels to each datum. These ids for object
#    2891         constancy of data points during animation. Should be an
#    2892         array of strings, not numbers or any other type.
#    2893     idssrc
#    2894         Sets the source reference on Chart Studio Cloud for
#    2895         `ids`.
#    2896     insidetextanchor
#    2897         Determines if texts are kept at center or start/end
#    2898         points in `textposition` "inside" mode.
#    2899     insidetextfont
#    2900         Sets the font used for `text` lying inside the bar.
#    2901     legend
#    2902         Sets the reference to a legend to show this trace in.
#    2903         References to these legends are "legend", "legend2",
#    2904         "legend3", etc. Settings for these legends are set in
#    2905         the layout, under `layout.legend`, `layout.legend2`,
#    2906         etc.
#    2907     legendgroup
#    2908         Sets the legend group for this trace. Traces and shapes
#    2909         part of the same legend group hide/show at the same
#    2910         time when toggling legend items.
#    2911     legendgrouptitle
#    2912         :class:`plotly.graph_objects.bar.Legendgrouptitle`
#    2913         instance or dict with compatible properties
#    2914     legendrank
#    2915         Sets the legend rank for this trace. Items and groups
#    2916         with smaller ranks are presented on top/left side while
#    2917         with "reversed" `legend.traceorder` they are on
#    2918         bottom/right side. The default legendrank is 1000, so
#    2919         that you can use ranks less than 1000 to place certain
#    2920         items before all unranked items, and ranks greater than
#    2921         1000 to go after all unranked items. When having
#    2922         unranked or equal rank items shapes would be displayed
#    2923         after traces i.e. according to their order in data and
#    2924         layout.
#    2925     legendwidth
#    2926         Sets the width (in px or fraction) of the legend for
#    2927         this trace.
#    2928     marker
#    2929         :class:`plotly.graph_objects.bar.Marker` instance or
#    2930         dict with compatible properties
#    2931     meta
#    2932         Assigns extra meta information associated with this
#    2933         trace that can be used in various text attributes.
#    2934         Attributes such as trace `name`, graph, axis and
#    2935         colorbar `title.text`, annotation `text`
#    2936         `rangeselector`, `updatemenues` and `sliders` `label`
#    2937         text all support `meta`. To access the trace `meta`
#    2938         values in an attribute in the same trace, simply use
#    2939         `%{meta[i]}` where `i` is the index or key of the
#    2940         `meta` item in question. To access trace `meta` in
#    2941         layout attributes, use `%{data[n[.meta[i]}` where `i`
#    2942         is the index or key of the `meta` and `n` is the trace
#    2943         index.
#    2944     metasrc
#    2945         Sets the source reference on Chart Studio Cloud for
#    2946         `meta`.
#    2947     name
#    2948         Sets the trace name. The trace name appears as the
#    2949         legend item and on hover.
#    2950     offset
#    2951         Shifts the position where the bar is drawn (in position
#    2952         axis units). In "group" barmode, traces that set
#    2953         "offset" will be excluded and drawn in "overlay" mode
#    2954         instead.
#    2955     offsetgroup
#    2956         Set several traces linked to the same position axis or
# -> 2957         matching axes to the same offsetgroup where bars of the
#    2958         same position coordinate will line up.
#    2959     offsetsrc
#    2960         Sets the source reference on Chart Studio Cloud for
#    2961         `offset`.
#    2962     opacity
#    2963         Sets the opacity of the trace.
#    2964     orientation
#    2965         Sets the orientation of the bars. With "v" ("h"), the
#    2966         value of the each bar spans along the vertical
#    2967         (horizontal).
#    2968     outsidetextfont
#    2969         Sets the font used for `text` lying outside the bar.
#    2970     selected
#    2971         :class:`plotly.graph_objects.bar.Selected` instance or
#    2972         dict with compatible properties
#    2973     selectedpoints
#    2974         Array containing integer indices of selected points.
#    2975         Has an effect only for traces that support selections.
#    2976         Note that an empty array means an empty selection where
#    2977         the `unselected` are turned on for all points, whereas,
#    2978         any other non-array values means no selection all where
#    2979         the `selected` and `unselected` styles have no effect.
#    2980     showlegend
#    2981         Determines whether or not an item corresponding to this
#    2982         trace is shown in the legend.
#    2983     stream
#    2984         :class:`plotly.graph_objects.bar.Stream` instance or
#    2985         dict with compatible properties
#    2986     text
#    2987         Sets text elements associated with each (x,y) pair. If
#    2988         a single string, the same string appears over all the
#    2989         data points. If an array of string, the items are
#    2990         mapped in order to the this trace's (x,y) coordinates.
#    2991         If trace `hoverinfo` contains a "text" flag and
#    2992         "hovertext" is not set, these elements will be seen in
#    2993         the hover labels.
#    2994     textangle
#    2995         Sets the angle of the tick labels with respect to the
#    2996         bar. For example, a `tickangle` of -90 draws the tick
#    2997         labels vertically. With "auto" the texts may
#    2998         automatically be rotated to fit with the maximum size
#    2999         in bars.
#    3000     textfont
#    3001         Sets the font used for `text`.
#    3002     textposition
#    3003         Specifies the location of the `text`. "inside"
#    3004         positions `text` inside, next to the bar end (rotated
#    3005         and scaled if needed). "outside" positions `text`
#    3006         outside, next to the bar end (scaled if needed), unless
#    3007         there is another bar stacked on this one, then the text
#    3008         gets pushed inside. "auto" tries to position `text`
#    3009         inside the bar, but if the bar is too small and no bar
#    3010         is stacked on this one the text is moved outside. If
#    3011         "none", no text appears.
#    3012     textpositionsrc
#    3013         Sets the source reference on Chart Studio Cloud for
#    3014         `textposition`.
#    3015     textsrc
#    3016         Sets the source reference on Chart Studio Cloud for
#    3017         `text`.
#    3018     texttemplate
#    3019         Template string used for rendering the information text
#    3020         that appear on points. Note that this will override
#    3021         `textinfo`. Variables are inserted using %{variable},
#    3022         for example "y: %{y}". Numbers are formatted using
#    3023         d3-format's syntax %{variable:d3-format}, for example
#    3024         "Price: %{y:$.2f}".
#    3025         https://github.com/d3/d3-format/tree/v1.4.5#d3-format
#    3026         for details on the formatting syntax. Dates are
#    3027         formatted using d3-time-format's syntax
#    3028         %{variable|d3-time-format}, for example "Day:
#    3029         %{2019-01-01|%A}". https://github.com/d3/d3-time-
#    3030         format/tree/v2.2.3#locale_format for details on the
#    3031         date formatting syntax. Every attributes that can be
#    3032         specified per-point (the ones that are `arrayOk: true`)
#    3033         are available. Finally, the template string has access
#    3034         to variables `value` and `label`.
#    3035     texttemplatesrc
#    3036         Sets the source reference on Chart Studio Cloud for
#    3037         `texttemplate`.
#    3038     uid
#    3039         Assign an id to this trace, Use this to provide object
#    3040         constancy between traces during animations and
#    3041         transitions.
#    3042     uirevision
#    3043         Controls persistence of some user-driven changes to the
#    3044         trace: `constraintrange` in `parcoords` traces, as well
#    3045         as some `editable: true` modifications such as `name`
#    3046         and `colorbar.title`. Defaults to `layout.uirevision`.
#    3047         Note that other user-driven trace attribute changes are
#    3048         controlled by `layout` attributes: `trace.visible` is
#    3049         controlled by `layout.legend.uirevision`,
#    3050         `selectedpoints` is controlled by
#    3051         `layout.selectionrevision`, and `colorbar.(x|y)`
#    3052         (accessible with `config: {editable: true}`) is
#    3053         controlled by `layout.editrevision`. Trace changes are
#    3054         tracked by `uid`, which only falls back on trace index
#    3055         if no `uid` is provided. So if your app can add/remove
#    3056         traces before the end of the `data` array, such that
#    3057         the same trace has a different index, you can still
#    3058         preserve user-driven changes if you give each trace a
#    3059         `uid` that stays with it as it moves.
#    3060     unselected
#    3061         :class:`plotly.graph_objects.bar.Unselected` instance
#    3062         or dict with compatible properties
#    3063     visible
#    3064         Determines whether or not this trace is visible. If
#    3065         "legendonly", the trace is not drawn, but can appear as
#    3066         a legend item (provided that the legend itself is
#    3067         visible).
#    3068     width
#    3069         Sets the bar width (in position axis units).
#    3070     widthsrc
#    3071         Sets the source reference on Chart Studio Cloud for
#    3072         `width`.
#    3073     x
#    3074         Sets the x coordinates.
#    3075     x0
#    3076         Alternate to `x`. Builds a linear space of x
#    3077         coordinates. Use with `dx` where `x0` is the starting
#    3078         coordinate and `dx` the step.
#    3079     xaxis
#    3080         Sets a reference between this trace's x coordinates and
#    3081         a 2D cartesian x axis. If "x" (the default value), the
#    3082         x coordinates refer to `layout.xaxis`. If "x2", the x
#    3083         coordinates refer to `layout.xaxis2`, and so on.
#    3084     xcalendar
#    3085         Sets the calendar system to use with `x` date data.
#    3086     xhoverformat
#    3087         Sets the hover text formatting rulefor `x`  using d3
#    3088         formatting mini-languages which are very similar to
#    3089         those in Python. For numbers, see:
#    3090         https://github.com/d3/d3-format/tree/v1.4.5#d3-format.
#    3091         And for dates see: https://github.com/d3/d3-time-
#    3092         format/tree/v2.2.3#locale_format. We add two items to
#    3093         d3's date formatter: "%h" for half of the year as a
#    3094         decimal number as well as "%{n}f" for fractional
#    3095         seconds with n digits. For example, *2016-10-13
#    3096         09:15:23.456* with tickformat "%H~%M~%S.%2f" would
#    3097         display *09~15~23.46*By default the values are
#    3098         formatted using `xaxis.hoverformat`.
#    3099     xperiod
#    3100         Only relevant when the axis `type` is "date". Sets the
#    3101         period positioning in milliseconds or "M<n>" on the x
#    3102         axis. Special values in the form of "M<n>" could be
#    3103         used to declare the number of months. In this case `n`
#    3104         must be a positive integer.
#    3105     xperiod0
#    3106         Only relevant when the axis `type` is "date". Sets the
#    3107         base for period positioning in milliseconds or date
#    3108         string on the x0 axis. When `x0period` is round number
#    3109         of weeks, the `x0period0` by default would be on a
#    3110         Sunday i.e. 2000-01-02, otherwise it would be at
#    3111         2000-01-01.
#    3112     xperiodalignment
#    3113         Only relevant when the axis `type` is "date". Sets the
#    3114         alignment of data points on the x axis.
#    3115     xsrc
#    3116         Sets the source reference on Chart Studio Cloud for
#    3117         `x`.
#    3118     y
#    3119         Sets the y coordinates.
#    3120     y0
#    3121         Alternate to `y`. Builds a linear space of y
#    3122         coordinates. Use with `dy` where `y0` is the starting
#    3123         coordinate and `dy` the step.
#    3124     yaxis
#    3125         Sets a reference between this trace's y coordinates and
#    3126         a 2D cartesian y axis. If "y" (the default value), the
#    3127         y coordinates refer to `layout.yaxis`. If "y2", the y
#    3128         coordinates refer to `layout.yaxis2`, and so on.
#    3129     ycalendar
#    3130         Sets the calendar system to use with `y` date data.
#    3131     yhoverformat
#    3132         Sets the hover text formatting rulefor `y`  using d3
#    3133         formatting mini-languages which are very similar to
#    3134         those in Python. For numbers, see:
#    3135         https://github.com/d3/d3-format/tree/v1.4.5#d3-format.
#    3136         And for dates see: https://github.com/d3/d3-time-
#    3137         format/tree/v2.2.3#locale_format. We add two items to
#    3138         d3's date formatter: "%h" for half of the year as a
#    3139         decimal number as well as "%{n}f" for fractional
#    3140         seconds with n digits. For example, *2016-10-13
#    3141         09:15:23.456* with tickformat "%H~%M~%S.%2f" would
#    3142         display *09~15~23.46*By default the values are
#    3143         formatted using `yaxis.hoverformat`.
#    3144     yperiod
#    3145         Only relevant when the axis `type` is "date". Sets the
#    3146         period positioning in milliseconds or "M<n>" on the y
#    3147         axis. Special values in the form of "M<n>" could be
#    3148         used to declare the number of months. In this case `n`
#    3149         must be a positive integer.
#    3150     yperiod0
#    3151         Only relevant when the axis `type` is "date". Sets the
#    3152         base for period positioning in milliseconds or date
#    3153         string on the y0 axis. When `y0period` is round number
#    3154         of weeks, the `y0period0` by default would be on a
#    3155         Sunday i.e. 2000-01-02, otherwise it would be at
#    3156         2000-01-01.
#    3157     yperiodalignment
#    3158         Only relevant when the axis `type` is "date". Sets the
#    3159         alignment of data points on the y axis.
#    3160     ysrc
#    3161         Sets the source reference on Chart Studio Cloud for
#    3162         `y`.
#    3163     zorder
#    3164         Sets the layer on which this trace is displayed,
#    3165         relative to other SVG traces on the same subplot. SVG
#    3166         traces with higher `zorder` appear in front of those
#    3167         with lower `zorder`.
#    3168
#    3169     Returns
#    3170     -------
#    3171     Bar
#    3172     """
#    3173     super(Bar, self).__init__("bar")
#    3175     if "_parent" in kwargs:
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\basedatatypes.py:4796, in __setitem__(self, prop, value)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\basedatatypes.py:5207, in _set_compound_prop(self, prop, val)
#    5203     else:
#    5204         raise err
#    5206 # val is None
# -> 5207 # -----------
#    5208 if val is None:
#    5209     # Check if we should send null update
#    5210     if self._props and prop in self._props:
#    5211         # Remove property if not in batch mode
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\_plotly_utils\basevalidators.py:2450, in validate_coerce(self, v, skip_invalid, _validate)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\graph_objs\bar\_marker.py:1203, in Marker.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, cornerradius, line, opacity, opacitysrc, pattern, reversescale, showscale, **kwargs)
#    1201 _v = line if line is not None else _v
#    1202 if _v is not None:
# -> 1203     self["line"] = _v
#    1204 _v = arg.pop("opacity", None)
#    1205 _v = opacity if opacity is not None else _v
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\basedatatypes.py:4796, in __setitem__(self, prop, value)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\basedatatypes.py:5207, in _set_compound_prop(self, prop, val)
#    5203     else:
#    5204         raise err
#    5206 # val is None
# -> 5207 # -----------
#    5208 if val is None:
#    5209     # Check if we should send null update
#    5210     if self._props and prop in self._props:
#    5211         # Remove property if not in batch mode
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\_plotly_utils\basevalidators.py:2450, in validate_coerce(self, v, skip_invalid, _validate)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\graph_objs\bar\marker\_line.py:626, in Line.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorscale, colorsrc, reversescale, width, widthsrc, **kwargs)
#     624 _v = color if color is not None else _v
#     625 if _v is not None:
# --> 626     self["color"] = _v
#     627 _v = arg.pop("coloraxis", None)
#     628 _v = coloraxis if coloraxis is not None else _v
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\basedatatypes.py:4804, in __setitem__(self, prop, value)
#    4797 def __setitem__(self, prop, value):
#    4798     """
#    4799     Parameters
#    4800     ----------
#    4801     prop : str
#    4802         The name of a direct child of this object
#    4803
# -> 4804         Note: Setting nested properties using property path string or
#    4805         property path tuples is not supported.
#    4806     value
#    4807         New property value
#    4808
#    4809     Returns
#    4810     -------
#    4811     None
#    4812     """
#    4813     from _plotly_utils.basevalidators import (
#    4814         CompoundValidator,
#    4815         CompoundArrayValidator,
#    4816         BaseDataValidator,
#    4817     )
#    4819     # Normalize prop
#    4820     # --------------
#    4821     # Convert into a property tuple
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\basedatatypes.py:5148, in _set_prop(self, prop, val)
#    5130 def pop(self, key, *args):
#    5131     """
#    5132     Remove the value associated with the specified key and return it
#    5133
#    5134     Parameters
#    5135     ----------
#    5136     key: str
#    5137         Property name
#    5138     dflt
#    5139         The default value to return if key was not found in object
#    5140
#    5141     Returns
#    5142     -------
#    5143     value
#    5144         The removed value that was previously associated with key
#    5145
#    5146     Raises
#    5147     ------
# -> 5148     KeyError
#    5149         If key is not in object and no dflt argument specified
#    5150     """
#    5151     # Handle default
#    5152     if key not in self and args:
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\plotly\basedatatypes.py:5143, in _set_prop(self, prop, val)
#    5130 def pop(self, key, *args):
#    5131     """
#    5132     Remove the value associated with the specified key and return it
#    5133
#    5134     Parameters
#    5135     ----------
#    5136     key: str
#    5137         Property name
#    5138     dflt
#    5139         The default value to return if key was not found in object
#    5140
#    5141     Returns
#    5142     -------
# -> 5143     value
#    5144         The removed value that was previously associated with key
#    5145
#    5146     Raises
#    5147     ------
#    5148     KeyError
#    5149         If key is not in object and no dflt argument specified
#    5150     """
#    5151     # Handle default
#    5152     if key not in self and args:
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\_plotly_utils\basevalidators.py:1365, in validate_coerce(self, v, should_raise)
#    1353       valid_color_description = (
#    1354           valid_color_description
#    1355           + """
#    (...)   1359           )
#    1360       )
#    1362   if self.array_ok:
#    1363       valid_color_description = (
#    1364           valid_color_description
# -> 1365           + """
#    1366 - A list or array of any of the above"""
#    1367       )
#    1369   return valid_color_description
#
# File c:\Users\dawe2\Desktop\folder\koddila\stary\Lib\site-packages\_plotly_utils\basevalidators.py:277, in raise_invalid_val(self, v, inds)
#     266     """
#     267     Returns a string that describes the values that are acceptable
#     268     to the validator
#    (...)    273     For consistancy, string should have leading 4-space indent
#     274     """
#     275     raise NotImplementedError()
# --> 277 def raise_invalid_val(self, v, inds=None):
#     278     """
#     279     Helper method to raise an informative exception when an invalid
#     280     value is passed to the validate_coerce method.
#    (...)    292     ValueError
#     293     """
#     294     name = self.plotly_name
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of bar.marker.line
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color:
#             aliceblue, antiquewhite, aqua, aquamarine, azure,
#             beige, bisque, black, blanchedalmond, blue,
#             blueviolet, brown, burlywood, cadetblue,
#             chartreuse, chocolate, coral, cornflowerblue,
#             cornsilk, crimson, cyan, darkblue, darkcyan,
#             darkgoldenrod, darkgray, darkgrey, darkgreen,
#             darkkhaki, darkmagenta, darkolivegreen, darkorange,
#             darkorchid, darkred, darksalmon, darkseagreen,
#             darkslateblue, darkslategray, darkslategrey,
#             darkturquoise, darkviolet, deeppink, deepskyblue,
#             dimgray, dimgrey, dodgerblue, firebrick,
#             floralwhite, forestgreen, fuchsia, gainsboro,
#             ghostwhite, gold, goldenrod, gray, grey, green,
#             greenyellow, honeydew, hotpink, indianred, indigo,
#             ivory, khaki, lavender, lavenderblush, lawngreen,
#             lemonchiffon, lightblue, lightcoral, lightcyan,
#             lightgoldenrodyellow, lightgray, lightgrey,
#             lightgreen, lightpink, lightsalmon, lightseagreen,
#             lightskyblue, lightslategray, lightslategrey,
#             lightsteelblue, lightyellow, lime, limegreen,
#             linen, magenta, maroon, mediumaquamarine,
#             mediumblue, mediumorchid, mediumpurple,
#             mediumseagreen, mediumslateblue, mediumspringgreen,
#             mediumturquoise, mediumvioletred, midnightblue,
#             mintcream, mistyrose, moccasin, navajowhite, navy,
#             oldlace, olive, olivedrab, orange, orangered,
#             orchid, palegoldenrod, palegreen, paleturquoise,
#             palevioletred, papayawhip, peachpuff, peru, pink,
#             plum, powderblue, purple, red, rosybrown,
#             royalblue, rebeccapurple, saddlebrown, salmon,
#             sandybrown, seagreen, seashell, sienna, silver,
#             skyblue, slateblue, slategray, slategrey, snow,
#             springgreen, steelblue, tan, teal, thistle, tomato,
#             turquoise, violet, wheat, white, whitesmoke,
#             yellow, yellowgreen
#       - A number that will be interpreted as a color
#         according to bar.marker.line.colorscale
#       - A list or array of any of the above
